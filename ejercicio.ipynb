# %% [markdown]
# # Lo más importante
#
# - Matemáticas
# - Python
# - SQL
#
#     ![fotoooo.jpg](attachment:11ff56dd-67ad-43cc-9e59-b9607141c9dc.jpg)
#
# Otro tema importante es el **Bussiness Intelligence*. <br>*
# Si tienes dudas, puedes escribirme a <jaime.gonzalez@thebridgeschool.e>
#
# Y en esta página se aprende mucho de machine learning: [página de ML](https://www.kaggle.com/)
#
# # Ejercicio 2
#
# | Ramp Up | Data Analysi | Machine Learning | Data & Business |
# | --- | --- | ---| --- |
# | Python | EDA | Supervised | Productivización |
# | Estadística | R | Non supervised | Storytelling|
# | SQL | Feat.Eng | Deep Learning | API |3 |
#
#  ${\sqrt {3x-1}} + (1+x)^2$
